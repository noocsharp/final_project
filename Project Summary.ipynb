# %% [markdown]
# New well locations:
#
# Well 1 - Easting: 95,682  Northing: 0
#
# Well 2 - Easting: 95,682  Northing: 500
#
# Well 3 - Easting: 95,682  Northing: 1000
#
# Well 4 - Easting: 95,682  Northing: 1500
#
# Well 5 - Easting: 95,682  Northing: 2000
#
# Well 6 - Easting: 95,682  Northing: 2500
#
# Well 7 - Easting: 95,682  Northing: 3000
#
# Well 8 - Easting: 95,682  Northing: 3500
#
# Well 9 - Easting: 95,682  Northing: 4000
#
# Well 10 - Easting: 95,682  Northing: 4500
#
#
# Original Oil in Place (bbl):
#
# Well 1 - 1,979,680.25
#
# Well 2 - 1,978,698.5
#
# Well 3 - 1,977,717.25
#
# Well 4 - 1,976,735.25
#
# Well 5 - 1,975,754.0
#
# Well 6 - 1,974,772.25
#
# Well 7 - 1,973,790.5
#
# Well 8 - 1,972,808.5
#
# Well 9 - 1,971,826.75
#
# Well 10 - 1,970,845.25
#
#
# Number of frac stages: 100
#
# Higher numbers of frac stages correlated with greater oil production, so we chose to use the highest amount of precedented frac stages by matching the maximum number of stages used in the data.
#
#
# Wel Lengths: 4318 ft
#
# The well length was optimized to maximize the number of frac stages (because more frac stages was correlated with greater production) and minimize length (to optimize cost) by matching the shortest existing well that had 100 stages
#
#
# Amount of proppant per stage: 988860.8 lb
#
# Although the amount of proppant did not have a very strong correlation with oil production, there was a positive relationship that did not seem to level off, so we chose to use the largest amount of proppant used by any of the wells in the data.
#
# Pump rate: 294.9 ft^3/min
#
# Pump rate did not significantly affect oil production, so we chose to use the lowest rate that was used by a well with 100 frac stages to optimize cost.
